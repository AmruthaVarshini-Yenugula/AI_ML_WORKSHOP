# %%
name = input("Enter customer name:  ")
age = int(input ("Enter age: "))
balance = float(input("Enter account balance: "))
customer_details = (name,age,balance)
print(f"Hello {customer_details[0]},\n age:{customer_details[1]},\n balance:{customer_details[2]}")
print("\n Welcome to SBI Bank")
# Out:
# Hello Amrutha,
#  age:20,
#  balance:2000.0
#
#  Welcome to SBI Bank

# %%
saving_accounts,salary_accounts = input("Enter saving accounts and salary accounts :").split()
print("number of saving accounts: ",saving_accounts)
print("number of salary accounts: ",salary_accounts)
# Out:
# number of saving accounts:  34
# number of salary accounts:  56
